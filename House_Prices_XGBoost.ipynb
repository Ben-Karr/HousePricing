# %%
#import kaggle
import pandas as pd
from pathlib import Path

from sklearn.model_selection import train_test_split

import pickle
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_log_error
from sklearn.preprocessing import LabelEncoder

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
path = Path('data')
path.mkdir(parents=True, exist_ok=True)

# %%
with open(path / 'HousePrices_preproc_outliers.pkl', 'rb') as h:
    df_all = pickle.load(h)

# %%
# copies of the other notebook
miss_list = ['MSZoning_miss', 'LotFrontage_miss', 'Utilities_miss', 'Exterior1st_miss', 'Exterior2nd_miss', 'MasVnrType_miss',
             'MasVnrArea_miss', 'BsmtQual_miss', 'BsmtCond_miss', 'BsmtExposure_miss', 'BsmtFinType2_miss', 'Electrical_miss',
             'KitchenQual_miss', 'Functional_miss', 'GarageYrBlt_miss', 'GarageFinish_miss', 'GarageCars_miss',
             'GarageArea_miss', 'GarageQual_miss', 'GarageCond_miss', 'PoolQC_miss', 'MiscFeature_miss', 'SaleType_miss']

cat_names = ['MSSubClass','MSZoning','Street','Alley','LotShape','LandContour',
             'Utilities','LotConfig','LandSlope','Neighborhood','Condition1',
            'Condition2','BldgType','HouseStyle','OverallQual','OverallCond',
            'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType',
            'ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond',
            'BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC',
            'CentralAir','Electrical','BsmtFullBath','BsmtHalfBath','FullBath',
            'HalfBath','KitchenQual','TotRmsAbvGrd',
            'Functional','Fireplaces','FireplaceQu','GarageType','GarageYrBlt',
            'GarageFinish','GarageCars','GarageQual','GarageCond','PavedDrive',
            'PoolQC','Fence','MiscFeature','MoSold','YrSold','SaleType',
             'SaleCondition','YearBuilt','YearRemodAdd','BedroomAbvGr', 'KitchenAbvGr']

cat_names.extend(miss_list)

# %%
for c in cat_names:
    lbl = LabelEncoder() 
    lbl.fit(list(df_all[c].values))
    df_all[c] = lbl.transform(list(df_all[c].values))

# %%
train_df = df_all[df_all['is_test'] == False].drop('is_test', axis = 1)
test_df = df_all[df_all['is_test'] == True].drop('is_test', axis = 1)

test_ids = test_df['Id']
test_df.drop(['Id', 'SalePrice'], axis = 1, inplace = True)

y = np.log(train_df['SalePrice']) # predict the log of the SalePrice
X = train_df.drop(['SalePrice','Id'], axis = 1)

# %%
train_X, test_X, train_y, test_y = train_test_split(X.values, y.values, test_size = 0.2)

# %%
my_model = XGBRegressor(colsample_bytree=0.4,
                        gamma = 0.,
                        learning_rate = 0.05,
                        max_depth = 5,
                        min_child_weight = 1.7,
                        n_estimators = 1000, 
                        reg_alpha = 0.5,
                        reg_lambda = 0.6,
                        subsample = 0.5,
                        seed = 42,
                        objective = 'reg:squarederror'
                       )
my_model.fit(train_X, train_y, early_stopping_rounds = 5, eval_set = [(test_X,test_y)], verbose = True)
# Out:
# [0]	validation_0-rmse:10.9638
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:10.4171
# [2]	validation_0-rmse:9.89818
# [3]	validation_0-rmse:9.40466
# [4]	validation_0-rmse:8.93608
# [5]	validation_0-rmse:8.49156
# [6]	validation_0-rmse:8.06946
# [7]	validation_0-rmse:7.66891
# [8]	validation_0-rmse:7.28691
# [9]	validation_0-rmse:6.92415
# [10]	validation_0-rmse:6.57987
# [11]	validation_0-rmse:6.25199
# [12]	validation_0-rmse:5.94165
# [13]	validation_0-rmse:5.64524
# [14]	validation_0-rmse:5.36474
# [15]	validation_0-rmse:5.09767
# [16]	validation_0-rmse:4.84481
# [17]	validation_0-rmse:4.60384
# [18]	validation_0-rmse:4.37514
# [19]	validation_0-rmse:4.15861
# [20]	validation_0-rmse:3.95237
# [21]	validation_0-rmse:3.7572
# [22]	validation_0-rmse:3.5711
# [23]	validation_0-rmse:3.39468
# [24]	validation_0-rmse:3.22651
# [25]	validation_0-rmse:3.06704
# [26]	validation_0-rmse:2.91549
# [27]	validation_0-rmse:2.77093
# [28]	validation_0-rmse:2.63372
# [29]	validation_0-rmse:2.503
# [30]	validation_0-rmse:2.37934
# [31]	validation_0-rmse:2.2625
# [32]	validation_0-rmse:2.1515
# [33]	validation_0-rmse:2.04638
# [34]	validation_0-rmse:1.94532
# [35]	validation_0-rmse:1.84923
# [36]	validation_0-rmse:1.75823
# [37]	validation_0-rmse:1.67215
# [38]	validation_0-rmse:1.59095
# [39]	validation_0-rmse:1.51309
# [40]	validation_0-rmse:1.43838
# [41]	validation_0-rmse:1.36883
# [42]	validation_0-rmse:1.30143
# [43]	validation_0-rmse:1.23795
# [44]	validation_0-rmse:1.17741
# [45]	validation_0-rmse:1.12005
# [46]	validation_0-rmse:1.06598
# [47]	validation_0-rmse:1.01424
# [48]	validation_0-rmse:0.965235
# [49]	validation_0-rmse:0.918322
# [50]	validation_0-rmse:0.87507
# [51]	validation_0-rmse:0.833169
# [52]	validation_0-rmse:0.79441
# [53]	validation_0-rmse:0.757357
# [54]	validation_0-rmse:0.721401
# [55]	validation_0-rmse:0.687614
# [56]	validation_0-rmse:0.656475
# [57]	validation_0-rmse:0.625812
# [58]	validation_0-rmse:0.596559
# [59]	validation_0-rmse:0.568876
# [60]	validation_0-rmse:0.542425
# [61]	validation_0-rmse:0.517651
# [62]	validation_0-rmse:0.49427
# [63]	validation_0-rmse:0.472306
# [64]	validation_0-rmse:0.451068
# [65]	validation_0-rmse:0.43082
# [66]	validation_0-rmse:0.411972
# [67]	validation_0-rmse:0.39409
# [68]	validation_0-rmse:0.377535
# [69]	validation_0-rmse:0.361134
# [70]	validation_0-rmse:0.346222
# [71]	validation_0-rmse:0.331514
# [72]	validation_0-rmse:0.318083
# [73]	validation_0-rmse:0.305758
# [74]	validation_0-rmse:0.293656
# [75]	validation_0-rmse:0.282713
# [76]	validation_0-rmse:0.271773
# [77]	validation_0-rmse:0.261796
# [78]	validation_0-rmse:0.252053
# [79]	validation_0-rmse:0.243049
# [80]	validation_0-rmse:0.23479
# [81]	validation_0-rmse:0.226901
# [82]	validation_0-rmse:0.219177
# [83]	validation_0-rmse:0.212004
# [84]	validation_0-rmse:0.205086
# [85]	validation_0-rmse:0.198379
# [86]	validation_0-rmse:0.192457
# [87]	validation_0-rmse:0.187011
# [88]	validation_0-rmse:0.181642
# [89]	validation_0-rmse:0.176708
# [90]	validation_0-rmse:0.1721
# [91]	validation_0-rmse:0.167783
# [92]	validation_0-rmse:0.163761
# [93]	validation_0-rmse:0.160065
# [94]	validation_0-rmse:0.156635
# [95]	validation_0-rmse:0.153247
# [96]	validation_0-rmse:0.150317
# [97]	validation_0-rmse:0.147668
# [98]	validation_0-rmse:0.144871
# [99]	validation_0-rmse:0.142226
# [100]	validation_0-rmse:0.139925
# [101]	validation_0-rmse:0.137728
# [102]	validation_0-rmse:0.135541
# [103]	validation_0-rmse:0.133636
# [104]	validation_0-rmse:0.131683
# [105]	validation_0-rmse:0.130005
# [106]	validation_0-rmse:0.128797
# [107]	validation_0-rmse:0.127363
# [108]	validation_0-rmse:0.12592
# [109]	validation_0-rmse:0.124725
# [110]	validation_0-rmse:0.123683
# [111]	validation_0-rmse:0.122873
# [112]	validation_0-rmse:0.121787
# [113]	validation_0-rmse:0.120819
# [114]	validation_0-rmse:0.120016
# [115]	validation_0-rmse:0.119229
# [116]	validation_0-rmse:0.118415
# [117]	validation_0-rmse:0.117612
# [118]	validation_0-rmse:0.116855
# [119]	validation_0-rmse:0.116222
# [120]	validation_0-rmse:0.11551
# [121]	validation_0-rmse:0.11497
# [122]	validation_0-rmse:0.114538
# [123]	validation_0-rmse:0.11408
# [124]	validation_0-rmse:0.113472
# [125]	validation_0-rmse:0.112708
# [126]	validation_0-rmse:0.112105
# [127]	validation_0-rmse:0.111549
# [128]	validation_0-rmse:0.11112
# [129]	validation_0-rmse:0.110617
# [130]	validation_0-rmse:0.11025
# [131]	validation_0-rmse:0.109842
# [132]	validation_0-rmse:0.109517
# [133]	validation_0-rmse:0.109252
# [134]	validation_0-rmse:0.109009
# [135]	validation_0-rmse:0.108599
# [136]	validation_0-rmse:0.108385
# [137]	validation_0-rmse:0.108139
# [138]	validation_0-rmse:0.107788
# [139]	validation_0-rmse:0.107577
# [140]	validation_0-rmse:0.10748
# [141]	validation_0-rmse:0.107147
# [142]	validation_0-rmse:0.106788
# [143]	validation_0-rmse:0.106574
# [144]	validation_0-rmse:0.106434
# [145]	validation_0-rmse:0.106017
# [146]	validation_0-rmse:0.105792
# [147]	validation_0-rmse:0.105452
# [148]	validation_0-rmse:0.105193
# [149]	validation_0-rmse:0.105043
# [150]	validation_0-rmse:0.104965
# [151]	validation_0-rmse:0.104609
# [152]	validation_0-rmse:0.104314
# [153]	validation_0-rmse:0.104168
# [154]	validation_0-rmse:0.104072
# [155]	validation_0-rmse:0.103997
# [156]	validation_0-rmse:0.103856
# [157]	validation_0-rmse:0.103599
# [158]	validation_0-rmse:0.103481
# [159]	validation_0-rmse:0.103441
# [160]	validation_0-rmse:0.10336
# [161]	validation_0-rmse:0.103183
# [162]	validation_0-rmse:0.102889
# [163]	validation_0-rmse:0.102932
# [164]	validation_0-rmse:0.102871
# [165]	validation_0-rmse:0.102767
# [166]	validation_0-rmse:0.10258
# [167]	validation_0-rmse:0.102411
# [168]	validation_0-rmse:0.102314
# [169]	validation_0-rmse:0.102172
# [170]	validation_0-rmse:0.102214
# [171]	validation_0-rmse:0.102259
# [172]	validation_0-rmse:0.102116
# [173]	validation_0-rmse:0.102256
# [174]	validation_0-rmse:0.102175
# [175]	validation_0-rmse:0.102073
# [176]	validation_0-rmse:0.101838
# [177]	validation_0-rmse:0.101864
# [178]	validation_0-rmse:0.101758
# [179]	validation_0-rmse:0.101709
# [180]	validation_0-rmse:0.101523
# [181]	validation_0-rmse:0.101575
# [182]	validation_0-rmse:0.101483
# [183]	validation_0-rmse:0.101225
# [184]	validation_0-rmse:0.101137
# [185]	validation_0-rmse:0.101278
# [186]	validation_0-rmse:0.101187
# [187]	validation_0-rmse:0.101188
# [188]	validation_0-rmse:0.101197
# [189]	validation_0-rmse:0.101087
# [190]	validation_0-rmse:0.101042
# [191]	validation_0-rmse:0.100976
# [192]	validation_0-rmse:0.100866
# [193]	validation_0-rmse:0.100897
# [194]	validation_0-rmse:0.100826
# [195]	validation_0-rmse:0.100778
# [196]	validation_0-rmse:0.100597
# [197]	validation_0-rmse:0.100629
# [198]	validation_0-rmse:0.100568
# [199]	validation_0-rmse:0.10046
# [200]	validation_0-rmse:0.100463
# [201]	validation_0-rmse:0.10033
# [202]	validation_0-rmse:0.100449
# [203]	validation_0-rmse:0.10049
# [204]	validation_0-rmse:0.100571
# [205]	validation_0-rmse:0.100739
# [206]	validation_0-rmse:0.100748
# Stopping. Best iteration:
# [201]	validation_0-rmse:0.10033
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0.0,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=5, min_child_weight=1.7, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=0, reg_alpha=0.5, reg_lambda=0.6, scale_pos_weight=1,
#              seed=42, silent=None, subsample=0.5, verbosity=1)

# %%
my_model = XGBRegressor(colsample_bytree=0.4,
                        gamma = 0.,
                        learning_rate = 0.05,
                        max_depth = 5,
                        min_child_weight = 1.7,
                        n_estimators = 1000, 
                        reg_alpha = 0.5,
                        reg_lambda = 0.6,
                        subsample = 0.5,
                        seed = 42,
                        objective = 'reg:squarederror'
                       )
my_model.fit(X.values, y.values, verbose = False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0.0,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=5, min_child_weight=1.7, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=0, reg_alpha=0.5, reg_lambda=0.6, scale_pos_weight=1,
#              seed=42, silent=None, subsample=0.5, verbosity=1)

# %%
# Just out of curiosity
predictions = my_model.predict(X.values)
print("MAE: " + str(np.sqrt(mean_squared_log_error(predictions, y.values))))
# Out:
# MAE: 0.002963367041961072

# %%
# Remove .round() when combined with NN
predictions = np.exp(my_model.predict(test_df.values)).round()

# %%
submission = pd.DataFrame({'Id': test_ids, 'SalePrice': predictions})
submission.to_csv(path / 'submission_xgb_all.csv', index = False)
submission.head()
# Out:
#      Id  SalePrice
# 0  1461   124867.0
# 1  1462   163610.0
# 2  1463   184957.0
# 3  1464   195666.0
# 4  1465   186796.0
